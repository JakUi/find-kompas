# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>")) #здесь можно задать ширину ячейки в % ширины экрана
# Out:
# <style>.container { width:90% !important; }</style>

# %%
vital = ['kch', 'лср', 'lsr', 'дык', 'лрс', 'мосстройреконструкция', 'khc', 'гдск', 'ulcr', 'gdsk', 'дск', 'л с р', '3250101', '325-01-01', '325 0101', '325 01 01', 'ленстройреконструкция', '326-01-01', '3260101', '326 01 01', 'k c h', 'irs', 'lrs', 'djhj;ltybt', 
         'возрождение', 'гск', 'пвыл', 'пвл', 'lcr', '228.*22.*88', '139.*29.*59', 'slr', 'лск недвижимост', 'isr\.ru']

donskoy = ['донской олимп', 'грюнвальд', 'лучи', 'новое домодедово', 'новое нахабино', 'шуваловск', 'новая охта', 'цивилизац', 'цевилизация', 'софия', 'софии', 'парус', 'акватория', 'калина парк', 'калейдоскоп', 'квартет', 
           'синема', 'цветной город', 'вива', 'три ветра', 'европа сити', 'калина-парк', 'нео', 'аврора', 'богемия', 'neo', 'пулковский посад', 'охта на речке', 'жк охта', 'yjdfz j\[nf', 'yjdfz j\[nf', '3 ветра', 'viva', 
           'антей', 'восток', 'yjdfz j\[nf', 'iedfkjdcrbq', 'cjabz', 'cinema', 'neva haus', 'nhb dtnhf', 'шувалов', ';yfz frdfnjhbz', 'wbdbkbpfwbz', 'gfhecf', 'русский дом', 'новой охте', 'verona', 'верона', 'кирочная 39',
           'wdtnyjq ujhjl', 'смольный парк', 'акватории', 'новая охота', 'новая\+охта', 'цветной\+город', 'dbdf', 'калина\+парк', 'радищева 39', 'rdfhntn', '3 dtnhf', 'jtvbz', 'fyntq', 'gfhec', 'iedfkjdcrq', 'rfktqljcrjg', 
           'rfkbyf gfhr', 'европа-сити', 'синема', 'edhjggf cbnb', 'europe city', 'evropa citi', 'gekrjdcrbqq gjcfl','iedfkjcrbq', 'neva art', 'neva hаus', 'dbdt', 'dbdf', 'wbdbpfwbz', 'yjdjq j\[nt', 'yjdfzj\[nf', 'yjdfz j\[nf', 
           'дворянск', 'богема', 'софья', 'зилар', 'дуэт', 'цветочный город', 'нева хаус', 'дует', 'pdtplysq len', 'каледоскоп', 'смольный квартал', 'neva.haus', 'kcg ytldb;bvjcnm', '; cjabb', 'зил.ар.', 'нахабино.ясн', 
           'ясное нахабино', 'ленинграd', 'ленинградка.58', 'ленинграда.58', 'лениградка.58', 'leningradka.58', 'ленинградка.58', 'ленинградка58', 'leningradka58', 'цветной бульвар', 'восход', 'меридиан', 'мередиан', 
           'флагман', 'расточная', 'жк на расточной', 'дом на расточной', 'мичуринский', 'мечуринский', 'хрустал', 'калиновский', 'рассветный', 'восток', 'зелен', 'берез', 'серебр', 'жк восточный', 'татищ', 'vthblbfy', 
           'akfuvfy', 'hfccdtny', 'vbxeh', 'djc', 'невский 68', 'riviere noire', 'нуар', 'жк ручьи', 'river noir', 'колейдоскоп', ';r ytj', 'ривер ноир', 'ривере норе', 'ривьера нойре', 'ручьи', '\[hecnfkmyst rk\.xb',
           'нэо парк', ';r hexmb', ';r kexb', 'riviera noir', 'rivier noir', 'neva house', 'ривьера ноире', 'цветном городе', 'нэо', 'ривьера ноир', 'нева хауз', 'нева.хаус', 'морская набережная', 'нева.хаус',
           'нева.резиденс', 'нева.haus', 'нева.арт', 'neva.residence', 'nevahaus', 'nevaresidence', 'neva хаус', 'заповедная', 'заповедный', 'зел.ный мыс', 'sea view', 'seaview', 'си вью', 'сивью', 'zilart', 'pbk.fhn',
           'pbkfhn', 'зил лот', 'лучах', 'kexb']

test_list = ['жк цивилизация спб', '( офис 219 8 343 216 ) | ( 35 62 8 343 201 )', '( паркингом районе проспекта мичуринский ул ) | ( пырьева подготовлена исходно разрешительная )', '3250101 квартиры лср', '_l.s.r', 'lcr недвижимость екатеринбург', 
             'гдск санкт-петербург', 'жк лср', 'жк шуваловский', 'жк москва екатеринбург официальный сайт', 'жк цветной бульвар', 'жк москва спб группа в контакте', 'квартиры в lsr', 'квартиры в лср недвижимость екатеринбург', 
             'заводская ул., 94, екатеринбург лср']
itog = dict()
vital_list = []
x = 0 #счётчик
#Проверяем каждый элемент списка vital на наличие его в строке-элементе списка test_list
for test in test_list:
    for vit in vital:
        if test.count(vit) != 0:
            category = 'vital'
            itog[test] = category
            print("Фраза: ", test)
            print("Ключ: ", vit)
            print("Категория: ", category)
for test in test_list:
    for don in donskoy:
        if test.count(don) != 0:
            for vit in vital:
                if test.count(vit) == 0:
                    print("Фраза: ", test)
                    print("Ключ: ", don)
                    print("Категория: Brend", )
                    itog[test] = 'Brend'
        #Пересчитать это
        #elif test.count(don) == 0:
        #    for vit in vital:
        #        if test.count(vit) == 0:
        #            x += 1
        #    if x == len(vital):
        #        itog[test] = 'Not Brend'
        #    x = 0
print('\n', itog)
# Out:
# Фраза:  3250101 квартиры лср
# Ключ:  лср
# Категория:  vital
# Фраза:  3250101 квартиры лср
# Ключ:  3250101
# Категория:  vital
# Фраза:  lcr недвижимость екатеринбург
# Ключ:  lcr
# Категория:  vital
# Фраза:  гдск санкт-петербург
# Ключ:  гдск
# Категория:  vital
# Фраза:  гдск санкт-петербург
# Ключ:  дск
# Категория:  vital
# Фраза:  жк лср
# Ключ:  лср
# Категория:  vital
# Фраза:  квартиры в lsr
# Ключ:  lsr
# Категория:  vital
# Фраза:  квартиры в лср недвижимость екатеринбург
# Ключ:  лср
# Категория:  vital
# Фраза:  заводская ул., 94, екатеринбург лср
# Ключ:  лср
# Категория:  vital
# Фраза:  заводская ул., 94, екатеринбург лср
# Ключ:  дск
# Категория:  vital
# Фраза:  жк цивилизация спб
# Ключ:  цивилизац
# Категория: Brend
# Фраза:  жк цивилизация спб
# Ключ:  цивилизац
# Категория: Brend
# Фраза:  жк цивилизация спб
# Ключ:  цивилизац
# Категория: Brend
# Фраза:  жк цивилизация спб
# Ключ:  цивилизац
# Категория: Brend
# Фраза:  жк цивилизация спб
# Ключ:  цивилизац
# ...

# %%
#Пробник. Верный
vital = ['kch', 'лср', 'lsr', 'дык', 'лрс', 'мосстройреконструкция', 'khc', 'гдск', 'ulcr', 'gdsk', 'дск', 'л с р', '3250101', '325-01-01', '325 0101', '325 01 01', 'ленстройреконструкция', '326-01-01', '3260101', '326 01 01', 'k c h', 'irs', 'lrs', 'djhj;ltybt', 
         'возрождение', 'гск', 'пвыл', 'пвл', 'lcr', '228.*22.*88', '139.*29.*59', 'slr', 'лск недвижимост', 'isr\.ru']

donskoy = ['донской олимп', 'грюнвальд', 'лучи', 'новое домодедово', 'новое нахабино', 'шуваловск', 'новая охта', 'цивилизац', 'цевилизация', 'софия', 'софии', 'парус', 'акватория', 'калина парк', 'калейдоскоп', 'квартет', 
           'синема', 'цветной город', 'вива', 'три ветра', 'европа сити', 'калина-парк', 'нео', 'аврора', 'богемия', 'neo', 'пулковский посад', 'охта на речке', 'жк охта', 'yjdfz j\[nf', 'yjdfz j\[nf', '3 ветра', 'viva', 
           'антей', 'восток', 'yjdfz j\[nf', 'iedfkjdcrbq', 'cjabz', 'cinema', 'neva haus', 'nhb dtnhf', 'шувалов', ';yfz frdfnjhbz', 'wbdbkbpfwbz', 'gfhecf', 'русский дом', 'новой охте', 'verona', 'верона', 'кирочная 39',
           'wdtnyjq ujhjl', 'смольный парк', 'акватории', 'новая охота', 'новая\+охта', 'цветной\+город', 'dbdf', 'калина\+парк', 'радищева 39', 'rdfhntn', '3 dtnhf', 'jtvbz', 'fyntq', 'gfhec', 'iedfkjdcrq', 'rfktqljcrjg', 
           'rfkbyf gfhr', 'европа-сити', 'синема', 'edhjggf cbnb', 'europe city', 'evropa citi', 'gekrjdcrbqq gjcfl','iedfkjcrbq', 'neva art', 'neva hаus', 'dbdt', 'dbdf', 'wbdbpfwbz', 'yjdjq j\[nt', 'yjdfzj\[nf', 'yjdfz j\[nf', 
           'дворянск', 'богема', 'софья', 'зилар', 'дуэт', 'цветочный город', 'нева хаус', 'дует', 'pdtplysq len', 'каледоскоп', 'смольный квартал', 'neva.haus', 'kcg ytldb;bvjcnm', '; cjabb', 'зил.ар.', 'нахабино.ясн', 
           'ясное нахабино', 'ленинграd', 'ленинградка.58', 'ленинграда.58', 'лениградка.58', 'leningradka.58', 'ленинградка.58', 'ленинградка58', 'leningradka58', 'цветной бульвар', 'восход', 'меридиан', 'мередиан', 
           'флагман', 'расточная', 'жк на расточной', 'дом на расточной', 'мичуринский', 'мечуринский', 'хрустал', 'калиновский', 'рассветный', 'восток', 'зелен', 'берез', 'серебр', 'жк восточный', 'татищ', 'vthblbfy', 
           'akfuvfy', 'hfccdtny', 'vbxeh', 'djc', 'невский 68', 'riviere noire', 'нуар', 'жк ручьи', 'river noir', 'колейдоскоп', ';r ytj', 'ривер ноир', 'ривере норе', 'ривьера нойре', 'ручьи', '\[hecnfkmyst rk\.xb',
           'нэо парк', ';r hexmb', ';r kexb', 'riviera noir', 'rivier noir', 'neva house', 'ривьера ноире', 'цветном городе', 'нэо', 'ривьера ноир', 'нева хауз', 'нева.хаус', 'морская набережная', 'нева.хаус',
           'нева.резиденс', 'нева.haus', 'нева.арт', 'neva.residence', 'nevahaus', 'nevaresidence', 'neva хаус', 'заповедная', 'заповедный', 'зел.ный мыс', 'sea view', 'seaview', 'си вью', 'сивью', 'zilart', 'pbk.fhn',
           'pbkfhn', 'зил лот', 'лучах', 'kexb']

test_list = ['жк цивилизация спб', '( офис 219 8 343 216 ) | ( 35 62 8 343 201 )', '( паркингом районе проспекта мичуринский ул ) | ( пырьева подготовлена исходно разрешительная )', '3250101 квартиры лср', '_l.s.r', 'lcr недвижимость екатеринбург', 
             'гдск санкт-петербург', 'жк лср', 'жк шуваловский', 'жк москва екатеринбург официальный сайт', 'жк цветной бульвар', 'жк москва спб группа в контакте', 'квартиры в lsr', 'квартиры в лср недвижимость екатеринбург', 
             'заводская ул., 94, екатеринбург лср', '7823477', 'хряк']
itog = dict()

for test in test_list:
    itog[test] = 'No brend'
    for vit in vital:
        if test.count(vit) != 0:
            category = 'Vital'
            itog[test] = category
            print("Фраза: ", test)
            print("Ключ: ", vit)
            print("Категория: ", category)
            break
    for don in donskoy:
        if test.count(don) != 0:
            category = 'Brend'
            itog[test] = category
            print("Фраза: ", test)
            print("Ключ: ", don)
            print("Категория: ", category)
            break      
        
print(itog)
# Out:
# Фраза:  жк цивилизация спб
# Ключ:  цивилизац
# Категория:  Brend
# Фраза:  ( паркингом районе проспекта мичуринский ул ) | ( пырьева подготовлена исходно разрешительная )
# Ключ:  мичуринский
# Категория:  Brend
# Фраза:  3250101 квартиры лср
# Ключ:  лср
# Категория:  Vital
# Фраза:  lcr недвижимость екатеринбург
# Ключ:  lcr
# Категория:  Vital
# Фраза:  гдск санкт-петербург
# Ключ:  гдск
# Категория:  Vital
# Фраза:  жк лср
# Ключ:  лср
# Категория:  Vital
# Фраза:  жк шуваловский
# Ключ:  шуваловск
# Категория:  Brend
# Фраза:  жк цветной бульвар
# Ключ:  цветной бульвар
# Категория:  Brend
# Фраза:  квартиры в lsr
# Ключ:  lsr
# Категория:  Vital
# Фраза:  квартиры в лср недвижимость екатеринбург
# Ключ:  лср
# Категория:  Vital
# Фраза:  заводская ул., 94, екатеринбург лср
# Ключ:  лср
# Категория:  Vital
# ...
